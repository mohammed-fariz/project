# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("clv_data.csv")

# %%
df.head()
# Out:
#      Order_ID Customer_ID        Date  Age  Gender      City Product_Category  \
# 0  ORD_001337  CUST_01337  2023-01-01   27  Female     Bursa             Toys
# 1  ORD_004885  CUST_04885  2023-01-01   42    Male     Konya             Toys
# 2  ORD_004507  CUST_04507  2023-01-01   43  Female    Ankara             Food
# 3  ORD_000645  CUST_00645  2023-01-01   32    Male  Istanbul      Electronics
# 4  ORD_000690  CUST_00690  2023-01-01   40  Female  Istanbul           Sports
#
#    Unit_Price  Quantity  Discount_Amount  Total_Amount    Payment_Method  \
# 0       54.28         1             0.00         54.28        Debit Card
# 1      244.90         1             0.00        244.90       Credit Card
# 2       48.15         5             0.00        240.75       Credit Card
# 3      804.06         1           229.28        574.78       Credit Card
# 4      755.61         5             0.00       3778.05  Cash on Delivery
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Order_ID                  5000 non-null   object
#  1   Customer_ID               5000 non-null   object
#  2   Date                      5000 non-null   object
#  3   Age                       5000 non-null   int64
#  4   Gender                    5000 non-null   object
#  5   City                      5000 non-null   object
#  6   Product_Category          5000 non-null   object
#  7   Unit_Price                5000 non-null   float64
#  8   Quantity                  5000 non-null   int64
#  9   Discount_Amount           5000 non-null   float64
#  10  Total_Amount              5000 non-null   float64
#  11  Payment_Method            5000 non-null   object
#  12  Device_Type               5000 non-null   object
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Order_ID                            object
# Customer_ID                         object
# Date                        datetime64[ns]
# Age                                  int64
# Gender                              object
# City                                object
# Product_Category                    object
# Unit_Price                         float64
# Quantity                             int64
# Discount_Amount                    float64
# Total_Amount                       float64
# Payment_Method                      object
# Device_Type                         object
# Session_Duration_Minutes             int64
# Pages_Viewed                         int64
# Is_Returning_Customer                 bool
# Delivery_Time_Days                   int64
# Customer_Rating                      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order_ID                    0
# Customer_ID                 0
# Date                        0
# Age                         0
# Gender                      0
# City                        0
# Product_Category            0
# Unit_Price                  0
# Quantity                    0
# Discount_Amount             0
# Total_Amount                0
# Payment_Method              0
# Device_Type                 0
# Session_Duration_Minutes    0
# Pages_Viewed                0
# Is_Returning_Customer       0
# Delivery_Time_Days          0
# Customer_Rating             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                                 Date          Age   Unit_Price     Quantity  \
# count                           5000  5000.000000  5000.000000  5000.000000
# mean   2023-08-16 09:16:24.959999744    35.032600   455.834120     2.220000
# min              2023-01-01 00:00:00    18.000000     5.180000     1.000000
# 25%              2023-04-30 00:00:00    27.000000    76.587500     1.000000
# 50%              2023-08-17 00:00:00    35.000000   182.950000     2.000000
# 75%              2023-12-06 00:00:00    42.000000   513.930000     3.000000
# max              2024-03-26 00:00:00    75.000000  7159.450000     5.000000
# std                              NaN    11.080546   712.477209     1.398711
#
#        Discount_Amount  Total_Amount  Session_Duration_Minutes  Pages_Viewed  \
# count      5000.000000   5000.000000                5000.00000    5000.00000
# mean         24.852804    983.108914                  14.57340       8.98420
# ...

# %%
sns.kdeplot(df['Total_Amount'])
# Out:
# <Axes: xlabel='Total_Amount', ylabel='Density'>

# %%
sns.kdeplot(df['Unit_Price'])
# Out:
# <Axes: xlabel='Unit_Price', ylabel='Density'>

# %%
sns.kdeplot(df['Discount_Amount'])
# Out:
# <Axes: xlabel='Discount_Amount', ylabel='Density'>

# %%
sns.boxplot(data=df[["Unit_Price", "Total_Amount", "Discount_Amount"]])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Unit_Price'])
# Out:
# <Axes: ylabel='Unit_Price'>

# %%
sns.boxplot(df['Total_Amount'])
# Out:
# <Axes: ylabel='Total_Amount'>

# %%
sns.boxplot(df['Discount_Amount'])
# Out:
# <Axes: ylabel='Discount_Amount'>

# %%
sns.boxplot(df['Discount_Amount'])
# Out:
# <Axes: ylabel='Discount_Amount'>

# %%
sns.boxplot(df['Customer_Rating'])
# Out:
# <Axes: ylabel='Customer_Rating'>

# %%
sns.barplot(data = df, x='Gender',y='Total_Amount',hue='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Total_Amount'>

# %%
gender_sum = df.groupby('Gender')['Total_Amount'].sum()

plt.figure(figsize=(7, 7))
plt.pie(gender_sum, labels=gender_sum.index, autopct='%1.2f%%')
plt.title('Total Amount by Gender')
plt.show()

# %%
df['Total_Amount'] = df['Total_Amount'].round(0).astype(int)

# %%
df[['Age','Unit_Price','Total_Amount','Discount_Amount']].skew()
# Out:
# Age                0.289229
# Unit_Price         1.203329
# Total_Amount       1.199866
# Discount_Amount    1.230025
# dtype: float64

# %%
num_cols = ["Unit_Price", "Total_Amount", "Discount_Amount"]

for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Cap and floor the outliers
    df[col] = df[col].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))

print(df[num_cols].describe())
# Out:
#         Unit_Price  Total_Amount  Discount_Amount
# count  5000.000000   5000.000000      5000.000000
# mean    353.589695    672.844000         5.219484
# std     372.751011    732.989914         8.713484
# min       5.180000      8.000000         0.000000
# 25%      76.587500    123.000000         0.000000
# 50%     182.950000    338.000000         0.000000
# 75%     513.930000    980.000000         8.760000
# max    1169.943750   2265.000000        21.900000

# %%
sns.kdeplot(df['Discount_Amount'])
# Out:
# <Axes: xlabel='Discount_Amount', ylabel='Density'>

# %%
sns.kdeplot(df['Unit_Price'])
# Out:
# <Axes: xlabel='Unit_Price', ylabel='Density'>

# %%
df[['Age','Unit_Price','Total_Amount','Discount_Amount']].skew()
# Out:
# Age                0.289229
# Unit_Price         1.203329
# Total_Amount       1.199866
# Discount_Amount    1.230025
# dtype: float64

# %%
sns.boxplot(data=df[["Unit_Price", "Total_Amount", "Discount_Amount"]])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Total_Amount'])
# Out:
# <Axes: ylabel='Total_Amount'>

# %% [markdown]
# univariate analysis

# %%
num_cols = ['Age', 'Unit_Price', 'Quantity', 'Discount_Amount', 'Total_Amount']
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Cap and floor the outliers
    df[col] = df[col].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))

# %%
num_cols = ['Age', 'Unit_Price', 'Quantity', 'Discount_Amount', 'Total_Amount']

for col in num_cols:
    plt.figure(figsize=(14,5))

    # Histogram + KDE
    plt.subplot(1,2,1)
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")

    # Boxplot
    plt.subplot(1,2,2)
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")

    plt.show()

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Date', 'Age', 'Gender', 'City',
#        'Product_Category', 'Unit_Price', 'Quantity', 'Discount_Amount',
#        'Total_Amount', 'Payment_Method', 'Device_Type',
#        'Session_Duration_Minutes', 'Pages_Viewed', 'Is_Returning_Customer',
#        'Delivery_Time_Days', 'Customer_Rating'],
#       dtype='object')

# %%
cat_cols = [
    'Gender',
    'City',

    
    
    'Product_Category',
    'Payment_Method',
    'Device_Type',
    'Is_Returning_Customer'
]

# %%
for col in cat_cols:
    plt.figure(figsize=(8,4))
    sns.countplot(x=df[col])
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# bivaraite analysis using target variable with categorical columns

# %%
target = 'Total_Amount'

cat_cols = [
    'Gender',
    'City',
    'Product_Category',
    'Payment_Method',
    'Device_Type',
    'Is_Returning_Customer'
]

for col in cat_cols:
    plt.figure(figsize=(14,5))

    # Barplot (Average spend)
    plt.subplot(1,2,1)
    sns.barplot(x=df[col], y=df[target])
    plt.title(f"Average Total Amount by {col}")
    plt.xticks(rotation=45)


    plt.tight_layout()
    plt.show()

# %%
num_cols = [
    'Age',
    'Unit_Price',
    'Quantity',
    'Discount_Amount',
    'Session_Duration_Minutes',
    'Pages_Viewed',
    'Delivery_Time_Days',
    'Customer_Rating'
]

for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=df[col], y=df[target])
    plt.title(f"{col} vs {target}")
    plt.show()

    print(f"Correlation ({col}, {target}): {df[col].corr(df[target]):.4f}")
    print("-"*70)
# Out:
# Correlation (Age, Total_Amount): -0.0004
# ----------------------------------------------------------------------
# Correlation (Unit_Price, Total_Amount): 0.8559
# ----------------------------------------------------------------------
# Correlation (Quantity, Total_Amount): 0.3793
# ----------------------------------------------------------------------
# Correlation (Discount_Amount, Total_Amount): 0.1091
# ----------------------------------------------------------------------
# Correlation (Session_Duration_Minutes, Total_Amount): 0.0001
# ----------------------------------------------------------------------
# Correlation (Pages_Viewed, Total_Amount): -0.0031
# ----------------------------------------------------------------------
# Correlation (Delivery_Time_Days, Total_Amount): 0.0037
# ----------------------------------------------------------------------
# Correlation (Customer_Rating, Total_Amount): -0.0031
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap (Numerical Features)")
plt.show()

# %% [markdown]
# multivariate analysis

# %%
# Numerical columns for pairplot
num_cols = ['Age', 'Unit_Price', 'Quantity', 'Discount_Amount', 'Total_Amount']

# Pairplot with hue='Gender'
sns.pairplot(df[num_cols + ['Gender']], hue='Gender', diag_kind='kde', palette='Set2')
plt.suptitle("Pairplot of Numerical Features by Gender", y=1.02)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Aggregate total amount per customer
customer_total = df.groupby('Customer_ID')['Total_Amount'].sum().reset_index()

# Select top 10 customers by spending
top_customers = customer_total.sort_values(by='Total_Amount', ascending=False).head(10)

# Bar plot
plt.figure(figsize=(10,6))
sns.barplot(data=top_customers, x='Customer_ID', y='Total_Amount', palette='viridis')
plt.title('Top 10 Customers by Total Spending')
plt.ylabel('Total Amount')
plt.xlabel('Customer ID')
plt.show()
print("Top 10 Customers by Total Spending:")
print(top_customers)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7712\638257482.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_customers, x='Customer_ID', y='Total_Amount', palette='viridis')
# Top 10 Customers by Total Spending:
#      Customer_ID  Total_Amount
# 2968  CUST_02969          2265
# 4163  CUST_04164          2265
# 1392  CUST_01393          2265
# 1983  CUST_01984          2265
# 759   CUST_00760          2265
# 757   CUST_00758          2265
# 2710  CUST_02711          2265
# 3772  CUST_03773          2265
# 1397  CUST_01398          2265
# 4540  CUST_04541          2265

# %%
# Aggregate total amount per customer
customer_total = df.groupby('Customer_ID')['Total_Amount'].sum().reset_index()

# Select top 10 customers by spending
lowest_customers = customer_total.sort_values(by='Total_Amount', ascending=True).head(10)

# Bar plot
plt.figure(figsize=(10,6))
sns.barplot(data=top_customers, x='Customer_ID', y='Total_Amount', palette='viridis')
plt.title('Top 10 Customers by Total Spending')
plt.ylabel('Total Amount')
plt.xlabel('Customer ID')
plt.show()
print("lowest 10 Customers by Total Spending:")
print(lowest_customers)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7712\2297690282.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_customers, x='Customer_ID', y='Total_Amount', palette='viridis')
# lowest 10 Customers by Total Spending:
#      Customer_ID  Total_Amount
# 3859  CUST_03860             8
# 2938  CUST_02939             8
# 119   CUST_00120             8
# 1595  CUST_01596             9
# 3039  CUST_03040            10
# 2885  CUST_02886            11
# 122   CUST_00123            11
# 4521  CUST_04522            11
# 4470  CUST_04471            12
# 2987  CUST_02988            12

# %%
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Sports           667
# Electronics      624
# Fashion          622
# Beauty           621
# Home & Garden    621
# Food             619
# Books            616
# Toys             610
# Name: count, dtype: int64

# %%
df['Unit_Price'].value_counts()
# Out:
# Unit_Price
# 1169.94375    513
# 30.10000        4
# 23.05000        3
# 31.33000        3
# 135.83000       3
#              ...
# 556.70000       1
# 813.32000       1
# 71.58000        1
# 254.43000       1
# 39.38000        1
# Name: count, Length: 4273, dtype: int64

# %%
df.nlargest(5, 'Unit_Price')[['Product_Category', 'Unit_Price']]
# Out:
#    Product_Category  Unit_Price
# 6       Electronics  1169.94375
# 9            Sports  1169.94375
# 19      Electronics  1169.94375
# 24      Electronics  1169.94375
# 28    Home & Garden  1169.94375

# %%
df.groupby('Product_Category')['Unit_Price'].min()
# Out:
# Product_Category
# Beauty            17.81
# Books             10.86
# Electronics      141.76
# Fashion           21.76
# Food               5.18
# Home & Garden     51.83
# Sports            34.78
# Toys              15.70
# Name: Unit_Price, dtype: float64
